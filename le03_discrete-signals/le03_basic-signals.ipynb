# %% [markdown]
# # Desafio
# Gere versões próprias dos seguintes sinais básicos:
# - $x[n] = \delta[n]$
# - $x[n] = u[n]$
# - $x[n] = A \sin (\omega n + \phi)$
# - $x[n] = | a |^n u[n], \quad | a | < 1 \quad \text{(BONUS)}$

# %%
# Delta signal
n = ...
x = ...

plt.subplots()
plt.stem(n, x)

# %%
# Unit step
n = ...
x = ...

plt.subplots()
plt.stem(n, x)

# %%
# The sinusoid
n = ...
x = ...

plt.subplots()
plt.stem(n, x)

# %%
# Exponential decay
n = ...
x = ...

plt.subplots()
plt.stem(n, x)
